# %% [markdown]
# -Data Collection

# %%
with open('../Cwh/Coders of banglore 3/finaldata.txt',encoding='utf-8') as f:
    data = f.read()

# %%
data
# Out:
# "techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes\n\nblrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes\n\nhsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com\n\ncloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud\n\nkoramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter\n\nai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & resea
# ...

# %%
chunkes = data.split('\n\n')
chunks = [c for c in chunkes if len(c) > 3]
print(chunks)
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes', 'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes', 'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com', 'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud', 'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter', 'ai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & rese
# ...

# %%
chunkes
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
# ...

# %%
chunkes[0]
# Out:
# 'techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'

# %%
chunkes[1]
# Out:
# 'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'

# %%
# Creat a function for seprate all users and their name vagera
def parse_chunk(chunk):
    chunk = chunk.strip()
    sep_chunk = chunk.split('\n')
    user_name = sep_chunk[0]
    No_of_posts = int(sep_chunk[1].split(" post")[0].replace(",",""))
    No_of_followers = float(sep_chunk[2].split(" follower")[0].replace(",","").replace("K","").replace("M",""))

# For Number of Follower 
    if ("K" in sep_chunk[2]):
        No_of_followers = int(No_of_followers * 1000)
    elif ("M" in sep_chunk[2]):
        No_of_followers = int(No_of_followers * 1000000)

    else:
        No_of_followers = int(No_of_followers)
# For Number of Following 
    No_of_following = sep_chunk[3]

    No_of_following = float(sep_chunk[3].split(" following")[0].replace(",","").replace("K","").replace("M",""))
    
    if ("K" in sep_chunk[3]):
        No_of_following = int(No_of_following * 1000)
    elif ("M" in sep_chunk[3]):
        No_of_following = int(No_of_following * 1000000)

    else:
        No_of_following = int(No_of_following)

    
    name = sep_chunk[4]
    if (len(sep_chunk) > 5):
        Type_of_page = sep_chunk[5]
        bio = "\n".join(sep_chunk[6:])
    else:
         Type_of_page = "Unknown"
         bio = ""

    return {"user_name":user_name,"No_of_posts":No_of_posts,"No_of_followers":No_of_followers,"No_of_following":No_of_following,
            "name":name,"Type_of_page":Type_of_page,"bio":bio}

# %%
# print(parse_chunk(chunks[0]))

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)

print(all_chunks)
# Out:
# [{'user_name': 'techie_koramangala', 'No_of_posts': 420, 'No_of_followers': 9800, 'No_of_following': 310, 'name': 'Arjun M.', 'Type_of_page': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'user_name': 'blrcoder_girl', 'No_of_posts': 150, 'No_of_followers': 6300, 'No_of_following': 120, 'name': 'Riya Codes', 'Type_of_page': 'Tech Creator', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'user_name': 'hsr_startup_stories', 'No_of_posts': 980, 'No_of_followers': 22400, 'No_of_following': 95, 'name': 'Startup Stories HSR', 'Type_of_page': 'Media', 'bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'user_name': 'cloud_dev_blr', 'No_of_posts': 210, 'No_of_followers': 4500, 'No_of_following': 60, 'name': 'Naveen DevOps', 'Type_of_page': 'Engineer', 'bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'},
# ...

# %%
import json
s = json.dumps(all_chunks,indent=4)
with open('data.json','w') as f:
    f.write(s)
print(s)
# Out:
# [
#     {
#         "user_name": "techie_koramangala",
#         "No_of_posts": 420,
#         "No_of_followers": 9800,
#         "No_of_following": 310,
#         "name": "Arjun M.",
#         "Type_of_page": "Software Engineer",
#         "bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "user_name": "blrcoder_girl",
#         "No_of_posts": 150,
#         "No_of_followers": 6300,
#         "No_of_following": 120,
#         "name": "Riya Codes",
#         "Type_of_page": "Tech Creator",
#         "bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "user_name": "hsr_startup_stories",
#         "No_of_posts": 980,
#         "No_of_followers": 22400,
#         "No_of_following": 95,
#         "name": "Startup Stories HSR",
#         "Type_of_page": "Media",
# ...

# %% [markdown]
# # Who Has The Maximum Posts

# %%
max = 0
for chunk in all_chunks:
    if (max < chunk['No_of_posts']):
        max = chunk['No_of_posts']
        chunk_with_max_post = chunk

print(chunk_with_max_post['user_name'])
# Out:
# startuphub_blr

# %% [markdown]
# # Who Has The Maximum Followers

# %%
max = 0
for chunk in all_chunks:
    if (max < chunk['No_of_followers']):
        max = chunk['No_of_followers']
        chunk_with_max_followers = chunk

print(chunk_with_max_followers['user_name'])
# Out:
# _anujsinghal

# %% [markdown]
# # Who Has The Maximum Following

# %%
max = 0
for chunk in all_chunks:
    if (max < chunk['No_of_following']):
        max = chunk['No_of_following']
        chunk_with_max_following = chunk

print(chunk_with_max_following)
# Out:
# {'user_name': 'bangalore_tech_bro', 'No_of_posts': 402, 'No_of_followers': 12500, 'No_of_following': 890, 'name': 'Rahul | HSR Hustler', 'Type_of_page': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %% [markdown]
# # How  Many Categories

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['Type_of_page'])

print(categories,len(categories))
# Out:
# {'Backend Developer', 'Founder', 'Developer', 'Artist + Coder', 'Educator', 'Media', 'Full-stack Dev', 'Design', 'Cafe Explorer', 'Recruiter', 'Cafe Nerd', 'Personal Blog', 'Entrepreneur', 'Public Figure', 'Digital creator', 'Data Scientist', 'Blogger', 'Lifestyle', 'Food & Drink', 'Blog', 'Data Science', 'Nonprofit organization', 'Community', 'Tech', 'Education', 'Investor', 'Software Engineer', 'Product Manager', 'Tech Creator', 'Engineer', 'Coder', 'Writer', 'Frontend Dev', 'Comedy'} 34

# %%
print(len(categories))
# Out:
# 34
