# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  Import Data 
data = pd.read_csv('./housing.csv')

# %%
data['income_category'] = pd.cut(data['median_income'],bins=[0,1.5,3.0,4.5,6.0 , np.inf], labels=[1,2,3,4,5])

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY
#
#   income_category
# 0               5
# 1               5
# ...

# %%
from sklearn.model_selection import  train_test_split
train_data ,test_data   =  train_test_split(data,test_size=0.2,random_state=42,stratify=data["income_category"])

# %%
test_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241     -118.39     34.12                  29         6447          1012.0
# 17352    -120.42     34.89                  24         2020           307.0
# 3505     -118.45     34.25                  36         1453           270.0
# 7777     -118.10     33.91                  35         1653           325.0
# 14155    -117.07     32.77                  38         3779           614.0
#
#        population  households  median_income  median_house_value  \
# 5241         2184         960         8.2816              500001
# 17352         855         283         5.0099              162500
# 3505          808         275         4.3839              204600
# 7777         1072         301         3.2708              159700
# 14155        1495         614         4.3529              184000
#
#       ocean_proximity income_category
# 5241        <1H OCEAN               5
# 17352       <1H OCEAN               4
# ...

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                  29         3873           797.0
# 15502    -117.23     33.09                   7         5320           855.0
# 2908     -119.04     35.37                  44         1618           310.0
# 14053    -117.13     32.75                  24         1877           519.0
# 20496    -118.70     34.28                  27         3536           646.0
#
#        population  households  median_income  median_house_value  \
# 12655        2237         706         2.1736               72100
# 15502        2015         768         6.3373              279600
# 2908          667         300         2.8750               82700
# 14053         898         483         2.2264              112500
# 20496        1837         580         4.4964              238300
#
#       ocean_proximity income_category
# 12655          INLAND               2
# 15502      NEAR OCEAN               5
# ...

# %%
# Let's we are delete income category column 
for catt in (train_data,test_data):
    catt.drop('income_category',axis=1,inplace=True)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                  29         3873           797.0
# 15502    -117.23     33.09                   7         5320           855.0
# 2908     -119.04     35.37                  44         1618           310.0
# 14053    -117.13     32.75                  24         1877           519.0
# 20496    -118.70     34.28                  27         3536           646.0
#
#        population  households  median_income  median_house_value  \
# 12655        2237         706         2.1736               72100
# 15502        2015         768         6.3373              279600
# 2908          667         300         2.8750               82700
# 14053         898         483         2.2264              112500
# 20496        1837         580         4.4964              238300
#
#       ocean_proximity
# 12655          INLAND
# 15502      NEAR OCEAN
# 2908           INLAND
# 14053      NEAR OCEAN
# ...

# %%
# Copy the test data
df = train_data.copy()

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                  29         3873           797.0
# 15502    -117.23     33.09                   7         5320           855.0
# 2908     -119.04     35.37                  44         1618           310.0
# 14053    -117.13     32.75                  24         1877           519.0
# 20496    -118.70     34.28                  27         3536           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                  14         6665          1231.0
# 12661    -121.42     38.51                  15         7901          1422.0
# 19263    -122.72     38.44                  48          707           166.0
# 19140    -122.70     38.31                  14         3155           580.0
# 19773    -122.14     39.97                  27         1079           222.0
#
# ...

# %%
# test_data

# %%
df.plot(kind='scatter' , x = 'latitude' , y='longitude' ,grid=True ,alpha=0.3)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
df.plot(kind='scatter' , x = 'latitude' , y='longitude' ,grid=True  , cmap='jet' , c="median_house_value")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
# df.drop(labels="ocean_proximity" , axis=1,inplace=True)
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # df.drop(labels="ocean_proximity" , axis=1,inplace=True)
# ----> 2 df.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
from pandas.plotting import scatter_matrix
attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
scatter_matrix(df[attributes], figsize=(12, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pandas.plotting import scatter_matrix
#       2 attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
# ----> 3 scatter_matrix(df[attributes], figsize=(12, 8))
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
data
